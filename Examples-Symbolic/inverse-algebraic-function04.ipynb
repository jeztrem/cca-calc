# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt

sym.init_printing()
x, y = sym.symbols('x y')

# %%
f = 42*x**3 + 3*x**3 + 2*x**2 + 7*x +1
eq = sym.Eq(y, f)
inverse_solved = sym.solve(eq, x)
print ("equation:")
display(eq)
print ("inverse:")
display(inverse_solved)
# Out:
# equation:
#         3      2
# y = 45⋅x  + 2⋅x  + 7⋅x + 1
# inverse:
# ⎡                       _____________________________________________________  ↪
# ⎢                      ╱              _____________________________            ↪
# ⎢                     ╱              ╱              2                          ↪
# ⎢                    ╱              ╱  ⎛49021   3⋅y⎞    3332950484             ↪
# ⎢                   ╱              ╱   ⎜───── - ───⎟  + ──────────             ↪
# ⎢  ⎛  1   √3⋅ⅈ⎞    ╱       3⋅y   ╲╱    ⎝91125    5 ⎠    8303765625    49021    ↪
# ⎢  ⎜- ─ - ────⎟⋅3 ╱      - ─── + ────────────────────────────────── + ──────   ↪
# ⎢  ⎝  2    2  ⎠ ╲╱         10                    2                    182250   ↪
# ⎢- ──────────────────────────────────────────────────────────────────────────  ↪
# ⎢                                      3                                       ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎣                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪    2                                          941                            ↪
# ↪ - ─── + ──────────────────────────────────────────────────────────────────── ↪
# ↪   135                             __________________________________________ ↪
# ↪                                  ╱              ____________________________ ↪
# ↪                                 ╱              ╱              2              ↪
# ↪                                ╱              ╱  ⎛49021   3⋅y⎞    3332950484 ↪
# ↪                               ╱              ╱   ⎜───── - ───⎟  + ────────── ↪
# ↪              ⎛  1   √3⋅ⅈ⎞    ╱       3⋅y   ╲╱    ⎝91125    5 ⎠    8303765625 ↪
# ↪         6075⋅⎜- ─ - ────⎟⋅3 ╱      - ─── + ───────────────────────────────── ↪
# ↪              ⎝  2    2  ⎠ ╲╱         10                    2                 ↪
#
# ↪                                     ________________________________________ ↪
# ↪                                    ╱              __________________________ ↪
# ↪                                   ╱              ╱              2            ↪
# ↪                                  ╱              ╱  ⎛49021   3⋅y⎞    33329504 ↪
# ↪                                 ╱              ╱   ⎜───── - ───⎟  + ──────── ↪
# ↪                ⎛  1   √3⋅ⅈ⎞    ╱       3⋅y   ╲╱    ⎝91125    5 ⎠    83037656 ↪
# ↪                ⎜- ─ + ────⎟⋅3 ╱      - ─── + ─────────────────────────────── ↪
# ↪                ⎝  2    2  ⎠ ╲╱         10                    2               ↪
# ↪ ───────────, - ───────────────────────────────────────────────────────────── ↪
# ↪ ___________                                        3                         ↪
# ↪ _                                                                            ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪     49021                                                                    ↪
# ↪ ─ + ──────                                                                   ↪
# ↪     182250                                                                   ↪
#
# ↪ _____________                                                                ↪
# ↪ ___                                                                          ↪
# ↪                                                                              ↪
# ↪ 84                                                                           ↪
# ↪ ──                                                                           ↪
# ↪ 25    49021                                                                  ↪
# ↪ ─── + ──────                                                                 ↪
# ↪       182250     2                                          941              ↪
# ↪ ───────────── - ─── + ────────────────────────────────────────────────────── ↪
# ↪                 135                             ____________________________ ↪
# ↪                                                ╱              ______________ ↪
# ↪                                               ╱              ╱               ↪
# ↪                                              ╱              ╱  ⎛49021   3⋅y⎞ ↪
# ↪                                             ╱              ╱   ⎜───── - ───⎟ ↪
# ↪                            ⎛  1   √3⋅ⅈ⎞    ╱       3⋅y   ╲╱    ⎝91125    5 ⎠ ↪
# ↪                       6075⋅⎜- ─ + ────⎟⋅3 ╱      - ─── + ─────────────────── ↪
# ↪                            ⎝  2    2  ⎠ ╲╱         10                    2   ↪
#
# ↪                                      _______________________________________ ↪
# ↪                                     ╱              _________________________ ↪
# ↪                                    ╱              ╱              2           ↪
# ↪                                   ╱              ╱  ⎛49021   3⋅y⎞    3332950 ↪
# ↪                                  ╱              ╱   ⎜───── - ───⎟  + ─────── ↪
# ↪                                 ╱       3⋅y   ╲╱    ⎝91125    5 ⎠    8303765 ↪
# ↪                              3 ╱      - ─── + ────────────────────────────── ↪
# ↪                              ╲╱         10                    2              ↪
# ↪ ─────────────────────────, - ─────────────────────────────────────────────── ↪
# ↪ _________________________                                  3                 ↪
# ↪ _______________                                                              ↪
# ↪ 2                                                                            ↪
# ↪     3332950484                                                               ↪
# ↪   + ──────────                                                               ↪
# ↪     8303765625    49021                                                      ↪
# ↪ ─────────────── + ──────                                                     ↪
# ↪                   182250                                                     ↪
#
# ↪ ______________                                                               ↪
# ↪ ____                                                                         ↪
# ↪                                                                              ↪
# ↪ 484                                                                          ↪
# ↪ ───                                                                          ↪
# ↪ 625    49021                                                                 ↪
# ↪ ──── + ──────                                                                ↪
# ↪        182250     2                                   941                    ↪
# ↪ ────────────── - ─── + ───────────────────────────────────────────────────── ↪
# ↪                  135                ________________________________________ ↪
# ↪                                    ╱              __________________________ ↪
# ↪                                   ╱              ╱              2            ↪
# ↪                                  ╱              ╱  ⎛49021   3⋅y⎞    33329504 ↪
# ↪                                 ╱              ╱   ⎜───── - ───⎟  + ──────── ↪
# ↪                                ╱       3⋅y   ╲╱    ⎝91125    5 ⎠    83037656 ↪
# ↪                        6075⋅3 ╱      - ─── + ─────────────────────────────── ↪
# ↪                             ╲╱         10                    2               ↪
#
# ↪              ⎤
# ↪              ⎥
# ↪              ⎥
# ↪              ⎥
# ↪              ⎥
# ↪              ⎥
# ↪              ⎥
# ↪              ⎥
# ↪ ─────────────⎥
# ↪ _____________⎥
# ↪ ___          ⎥
# ↪              ⎥
# ↪ 84           ⎥
# ↪ ──           ⎥
# ↪ 25    49021  ⎥
# ↪ ─── + ────── ⎥
# ↪       182250 ⎦

# %%
inverse_solved = sym.solve(eq, x)[0]

# %%
f_lambdified = sym.lambdify(x, f, 'numpy')
inv_lambdified = sym.lambdify(y, inverse_solved, 'numpy')

# %%
x_vals = np.linspace(-0.5, 0.5, 400)
y_vals = f_lambdified(x_vals)
inv_vals = inv_lambdified(y_vals)

# %%
plt.plot(x_vals, y_vals, label='$f(x)$', color='blue')
plt.plot(y_vals, inv_vals, label='$f^{-1}(x)$', color='red')

# find the min and max for the symmetry line and plot it
sym_min = min(np.min(x_vals), np.min(y_vals), np.min(inv_vals))
sym_max = max(np.max(x_vals), np.max(y_vals), np.max(inv_vals))
plt.plot([sym_min, sym_max], [sym_min, sym_max], color='black', linestyle='--')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Function, Inverse')
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.show()
