# %% [markdown]
# ### Chapter 2, Section 1: Tangent and Velocity problems
# ##### The first plot is of a parabola and it's tangent lines.
# ##### The second plot is same using x**3.
# ##### The third plot is same using x**4.

# %%
# Define x values
a = 5
x = np.linspace(-a, a, 400)
y = x**2

# Points where the tangent lines are computed.
x_points = np.linspace(-a, a, 11)
y_points = x_points**2
# Using the slope formula rise/run or (change in y)/(change = x)
delta = 0.3
slopes = ((x_points + delta)**2 - (x_points - delta)**2)/(2*delta)

# Set up subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Plot cos(x) and tangent lines
axs[0].plot(x, y, label='x*x', color='blue')
for x0, y0, m in zip(x_points, y_points, slopes):
    x_tangent = np.linspace(x0 - delta, x0 + delta, 10)
    y_tangent = m * (x_tangent - x0) + y0
    axs[0].plot(x_tangent, y_tangent, color='green',  linewidth=2)
axs[0].set_title('Parabola and Tangent Lines')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid(True)
axs[0].legend()

# Plot slope values
axs[1].plot(x_points, slopes, 'go-', label='Slope = 2x', markersize=6)
axs[1].set_title('Slope of Tangents to x*x')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Slope')
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Define x values
a = 5
x = np.linspace(-a, a, 400)
y = x**3

# Points where the tangent lines are computed.
x_points = np.linspace(-a, a, 11)
y_points = x_points**3
# Using the slope formula rise/run or (change in y)/(change = x)
delta = 0.5
slopes = ((x_points + delta)**3 - (x_points - delta)**3)/(2*delta)

# Set up subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Plot cos(x) and tangent lines
axs[0].plot(x, y, label='x**3', color='blue')
for x0, y0, m in zip(x_points, y_points, slopes):
    x_tangent = np.linspace(x0 - delta, x0 + delta, 10)
    y_tangent = m * (x_tangent - x0) + y0
    axs[0].plot(x_tangent, y_tangent, color='green',  linewidth=2)
axs[0].set_title('x**3 and Tangent Lines')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid(True)
axs[0].legend()

# Plot slope values
axs[1].plot(x_points, slopes, 'go-', label='Slope = 3x**2', markersize=6)
axs[1].set_title('Slope of Tangents to x**3')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Slope')
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Define x values
a = 5
x = np.linspace(-a, a, 400)
y = x**4

# Points where the tangent lines are computed.
x_points = np.linspace(-a, a, 11)
y_points = x_points**4
# Using the slope formula rise/run or (change in y)/(change = x)
delta = 0.3
slopes = ((x_points + delta)**4 - (x_points - delta)**4)/(2*delta)

# Set up subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Plot cos(x) and tangent lines
axs[0].plot(x, y, label='x*x', color='blue')
for x0, y0, m in zip(x_points, y_points, slopes):
    x_tangent = np.linspace(x0 - delta, x0 + delta, 10)
    y_tangent = m * (x_tangent - x0) + y0
    axs[0].plot(x_tangent, y_tangent, color='green',  linewidth=2)
axs[0].set_title('x**4 and Tangent Lines')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid(True)
axs[0].legend()

# Plot slope values
axs[1].plot(x_points, slopes, 'go-', label='Slope = 4x**3', markersize=6)
axs[1].set_title('Slope of Tangents to x**4')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Slope')
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()
