# %% [markdown]
# ### Chapter 2, Section 2: Limit of a Function
# - Below are the plots of the example functions on page 83 and 85.
# - The errors that are reported are intentional to demonstrate divide by zero.
# - Problems: Paper (5, 7 , 9, 29, 37, 41).
# - Problems: Jupyter (13, 21).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define x values, compute f(x)
a = 5
x = np.linspace(-a, a, 400)
y = ((x-1)/(x*x - 1))

# Plot f(x)
plt.plot(x, y, label=r'$\frac{x-1}{x^2 -1}$', color='black')
plt.title('Function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# %%
# Define x values, compute f(x)
x = np.linspace(-0.5, 2, 400)
y = ((x-1)/(x*x - 1))

# Plot f(x)
plt.plot(x, y, label=r'$\frac{x-1}{x^2 -1}$', color='black')
plt.title('Function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()

# %%
# Define x values, compute f(x)
x = np.linspace(0.95, 1.05, 99)
y = ((x-1)/(x*x - 1))

# Plot f(x)
plt.plot(x, y, label=r'$\frac{x-1}{x^2 -1}$', color='black')
plt.title('Function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
# Out:
# C:\Users\jeztr\AppData\Local\Temp\ipykernel_22884\95554430.py:3: RuntimeWarning: invalid value encountered in divide
#   y = ((x-1)/(x*x - 1))

# %%
# Define x values, compute f(x)
x = np.linspace(-1.05, 1.05, 99)
y = ((x*x+9)**0.5-3)/(x*x)

# Plot f(x)
plt.plot(x, y, label=r'$\frac{\sqrt{t^2 + 9} - 3}{t^2}$', color='black')
plt.title('Function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
# Out:
# C:\Users\jeztr\AppData\Local\Temp\ipykernel_22884\3688171269.py:3: RuntimeWarning: invalid value encountered in divide
#   y = ((x*x+9)**0.5-3)/(x*x)

# %%
# Define x values, compute f(x)
x = np.linspace(-0.00001, 0.00001, 99)
y = ((x*x+9)**0.5-3)/(x*x)

# Plot f(x)
plt.plot(x, y, label=r'$\frac{\sqrt{t^2 + 9} - 3}{t^2}$', color='black')

plt.title('Function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
# Out:
# C:\Users\jeztr\AppData\Local\Temp\ipykernel_22884\2564247223.py:3: RuntimeWarning: invalid value encountered in divide
#   y = ((x*x+9)**0.5-3)/(x*x)
